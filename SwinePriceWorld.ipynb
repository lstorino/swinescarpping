# %% [markdown]
# # 1. Capturing Pig Prices from the Web

# %% [markdown]
# # 1.2. Essential Python Libraries for data aquisition
# ### Data source from pig333

# %%
import bs4
import urllib.request as urllib_request
import pandas

print("BeautifulSoup ->", bs4.__version__)
print("urllib ->", urllib_request.__version__)
print("pandas ->", pandas.__version__)
# Out:
# BeautifulSoup -> 4.7.1
# urllib -> 3.7
# pandas -> 0.24.2

# %% [markdown]
# # 1.3. Poiting the scrapper to the right URL

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = 'https://www.pig333.com/markets_and_prices/'

response = urlopen(url)
html = response.read()
html = html.decode('utf-8')

soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="web">
#  <head>
#   <title>
#    Pig prices - pig333, pig to pork community
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="en" http-equiv="content-language"/>
#   <meta content="The latest slaughter pig prices in the most important pig markets. Check the evolution of the historical prices in charts and in several currencies." name="description"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta charset="utf-8"/>
#   <meta content="POnbcF9y7hlMA1qCHewt_IU_bNjPhXwcwidy38TUjms" name="google-site-verification"/>
#   <meta content="BG_3ZIOxC_wqzmPDZHbVdH-u5i_wLT5XdX2n_0_66Ck" name="google-site-verification"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:900,700,400|Lato:400,400i,700,900,900i|Merriweather&amp;display=swap&amp;subset=cyrillic,latin-ext" rel="stylesheet"/>
# ...

# %%
type(html)
# Out:
# str

# %%
" ".join(html.split())
# Out:
# '<!DOCTYPE html> <html class=\'web\'> <head> <title>Pig prices - pig333, pig to pork community</title> <meta http-equiv="content-type" content="text/html; charset=UTF-8" /> <meta http-equiv="content-language" content="en" /> <meta name=\'description\' content=\'The latest slaughter pig prices in the most important pig markets. Check the evolution of the historical prices in charts and in several currencies.\'/> <meta name=\'viewport\' content=\'width=device-width, initial-scale=1\' /> <meta charset="UTF-8" /> <meta name="google-site-verification" content="POnbcF9y7hlMA1qCHewt_IU_bNjPhXwcwidy38TUjms" /> <meta name="google-site-verification" content="BG_3ZIOxC_wqzmPDZHbVdH-u5i_wLT5XdX2n_0_66Ck" /> <link href="https://fonts.googleapis.com/css?family=Roboto:900,700,400|Lato:400,400i,700,900,900i|Merriweather&display=swap&subset=cyrillic,latin-ext" rel="stylesheet"> <link rel=\'stylesheet\' href=\'https://www.pig333.com/3tres3_common/dist_nou/css/web_new.css?t=20200703\' type=\'text/css\'
# ...

# %%
" ".join(html.split()).replace('> <', '><')
# Out:
# '<!DOCTYPE html><html class=\'web\'><head><title>Pig prices - pig333, pig to pork community</title><meta http-equiv="content-type" content="text/html; charset=UTF-8" /><meta http-equiv="content-language" content="en" /><meta name=\'description\' content=\'The latest slaughter pig prices in the most important pig markets. Check the evolution of the historical prices in charts and in several currencies.\'/><meta name=\'viewport\' content=\'width=device-width, initial-scale=1\' /><meta charset="UTF-8" /><meta name="google-site-verification" content="POnbcF9y7hlMA1qCHewt_IU_bNjPhXwcwidy38TUjms" /><meta name="google-site-verification" content="BG_3ZIOxC_wqzmPDZHbVdH-u5i_wLT5XdX2n_0_66Ck" /><link href="https://fonts.googleapis.com/css?family=Roboto:900,700,400|Lato:400,400i,700,900,900i|Merriweather&display=swap&subset=cyrillic,latin-ext" rel="stylesheet"><link rel=\'stylesheet\' href=\'https://www.pig333.com/3tres3_common/dist_nou/css/web_new.css?t=20200703\' type=\'text/css\' /><link rel
# ...

# %%
soup.get_text()
# Out:
# "\n\n\nPig prices - pig333, pig to pork community\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n        var _gaq = _gaq || [];\n        _gaq.push(['_setAccount', 'UA-108671-20']);\n        _gaq.push(['_trackPageview']);\n                _gaq.push(['b._setAccount', 'UA-108671-26']);\n        _gaq.push(['b._trackPageview']);\n        (function() {\n          var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;\n          ga.src = 'https://stats.g.doubleclick.net/dc.js';\n          var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);\n        })();\n        \nSIGN UPLOGINDirectoryClassifiedsTrainingShop333 Social Networkpig333.comProfessional Pig Community97,334 registered professionalsBeing registered in pig333.com has many advantages and it's completely free\n\n\nNews\n\n\n\n\nNewsNews, events and news reports of the pig industrySwine newsAbout 333ReportsCompany newsCalendarThe pig sector events all around the world\n\n\n
# ...

# %%
html.split()
# Out:
# ['<!DOCTYPE',
#  'html>',
#  '<html',
#  "class='web'>",
#  '<head>',
#  '<title>Pig',
#  'prices',
#  '-',
#  'pig333,',
#  'pig',
#  'to',
#  'pork',
#  'community</title>',
#  '<meta',
#  'http-equiv="content-type"',
#  'content="text/html;',
#  'charset=UTF-8"',
#  '/>',
#  '<meta',
#  'http-equiv="content-language"',
#  'content="en"',
#  '/>',
#  '<meta',
#  "name='description'",
#  "content='The",
#  'latest',
#  'slaughter',
#  'pig',
#  'prices',
#  'in',
#  'the',
#  'most',
#  'important',
#  'pig',
#  'markets.',
#  'Check',
#  'the',
#  'evolution',
#  'of',
#  'the',
#  'historical',
#  'prices',
#  'in',
#  'charts',
#  'and',
#  'in',
#  'several',
#  "currencies.'/>",
#  '<meta',
#  "name='viewport'",
#  "content='width=device-width,",
#  "initial-scale=1'",
#  '/>',
#  '<meta',
#  'charset="UTF-8"',
#  '/>',
#  '<meta',
#  'name="google-site-verification"',
#  'content="POnbcF9y7hlMA1qCHewt_IU_bNjPhXwcwidy38TUjms"',
#  '/>',
#  '<meta',
# ...

# %%
" ".join(html.split()).replace('> <', '><')
# Out:
# '<!DOCTYPE html><html class=\'web\'><head><title>Pig prices - pig333, pig to pork community</title><meta http-equiv="content-type" content="text/html; charset=UTF-8" /><meta http-equiv="content-language" content="en" /><meta name=\'description\' content=\'The latest slaughter pig prices in the most important pig markets. Check the evolution of the historical prices in charts and in several currencies.\'/><meta name=\'viewport\' content=\'width=device-width, initial-scale=1\' /><meta charset="UTF-8" /><meta name="google-site-verification" content="POnbcF9y7hlMA1qCHewt_IU_bNjPhXwcwidy38TUjms" /><meta name="google-site-verification" content="BG_3ZIOxC_wqzmPDZHbVdH-u5i_wLT5XdX2n_0_66Ck" /><link href="https://fonts.googleapis.com/css?family=Roboto:900,700,400|Lato:400,400i,700,900,900i|Merriweather&display=swap&subset=cyrillic,latin-ext" rel="stylesheet"><link rel=\'stylesheet\' href=\'https://www.pig333.com/3tres3_common/dist_nou/css/web_new.css?t=20200703\' type=\'text/css\' /><link rel
# ...

# %%
# Out:
# <bound method Tag.find_all of <img alt="https://www.pig333.com" class="tresos" src="https://www.pig333.com/3tres3_common/images/333-the200Challenge.svg"/>>

# %% [markdown]
# ### CONVERTING TO STRINGS

# %%
soup.html.head.title
# Out:
# <title>Pig prices - pig333, pig to pork community</title>

# %%
soup.title
# Out:
# <title>Pig prices - pig333, pig to pork community</title>

# %%
soup.title.get_text()
# Out:
# 'Pig prices - pig333, pig to pork community'

# %%
soup.h2.getText()
# Out:
# 'News'

# %%
soup.get_text()
# Out:
# "\n\n\nPig prices - pig333, pig to pork community\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n        var _gaq = _gaq || [];\n        _gaq.push(['_setAccount', 'UA-108671-20']);\n        _gaq.push(['_trackPageview']);\n                _gaq.push(['b._setAccount', 'UA-108671-26']);\n        _gaq.push(['b._trackPageview']);\n        (function() {\n          var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;\n          ga.src = 'https://stats.g.doubleclick.net/dc.js';\n          var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);\n        })();\n        \nSIGN UPLOGINDirectoryClassifiedsTrainingShop333 Social Networkpig333.comProfessional Pig Community97,334 registered professionalsBeing registered in pig333.com has many advantages and it's completely free\n\n\nNews\n\n\n\n\nNewsNews, events and news reports of the pig industrySwine newsAbout 333ReportsCompany newsCalendarThe pig sector events all around the world\n\n\n
# ...

# %% [markdown]
# ### CHECKING ON ALL IMAGES

# %%
soup('img')
# Out:
# [<img alt="https://www.pig333.com" class="tresos" src="https://www.pig333.com/3tres3_common/images/333-the200Challenge.svg"/>,
#  <img class="icona" src="https://www.pig333.com/3tres3_common/dist_nou/css/images/svg/agenda.svg" width="28"/>,
#  <img class="icona" src="https://www.pig333.com/3tres3_common/dist_nou/css/images/svg/pcv2.svg" width="28"/>,
#  <img class="icona" src="https://www.pig333.com/3tres3_common/dist_nou/css/images/svg/ppa.svg" width="28"/>,
#  <img class="icona" src="https://www.pig333.com/3tres3_common/dist_nou/css/images/svg/enfermedades.svg" width="28"/>,
#  <img class="icona" src="https://www.pig333.com/3tres3_common/dist_nou/css/images/svg/atlas.svg" width="28"/>,
#  <img class="icona" src="https://www.pig333.com/3tres3_common/dist_nou/css/images/svg/ediagnostico.svg" width="28"/>,
#  <img class="icona" src="https://www.pig333.com/3tres3_common/dist_nou/css/images/svg/diccionario.svg" width="28"/>,
# ...

# %% [markdown]
# ### CHECKING ON ALL TAG OF THE HTML

# %%
soup.findAll(['h1', 'h2', 'h3', 'h4'])
# Out:
# [<h2 class="mt0 pt0"><a href="https://www.pig333.com/news/" title="News">News</a></h2>,
#  <h3><a class="" href="https://www.pig333.com/calendar/" title="Calendar">Calendar</a></h3>,
#  <h2 class="mt0 pt0"><a href="https://www.pig333.com/health/" title="Health">Health</a></h2>,
#  <h3><a class="" href="https://www.pig333.com/pcv2/" title="PCVAD - Focus on Porcine circovirus associated disease">PCVAD - Focus on Porcine circovirus associated disease</a></h3>,
#  <h3><a class="" href="https://www.pig333.com/asf/" title="African Swine Fever">African Swine Fever</a></h3>,
#  <h3><a class="" href="https://www.pig333.com/pig-diseases/" title="Diseases manual">Diseases manual</a></h3>,
#  <h3><a class="" href="https://www.pig333.com/pathology-atlas/" title="Atlas of pathology">Atlas of pathology</a></h3>,
#  <h3><a class="" href="https://www.pig333.com/ediagnostics/" title="E-diagnostics">E-diagnostics</a></h3>,
# ...

# %% [markdown]
# ### CHECKING ON SPECIFIC ATTRIBUTES FOR THE INFORMATION YOU NEED

# %%
regions = soup.findAll('h3', {"class": "panel-title"})[0:3]
regions
# Out:
# [<h3 class="panel-title">Europe</h3>,
#  <h3 class="panel-title">America</h3>,
#  <h3 class="panel-title">Asia</h3>]

# %% [markdown]
# ### Searching for the tag price

# %%
soup.findAll('span', class_ = "preu")
# Out:
# [<span class="preu">0.940</span>,
#  <span class="preu">10.50</span>,
#  <span class="preu">1.293</span>,
#  <span class="preu">1.470</span>,
#  <span class="preu">1.275</span>,
#  <span class="preu">1.050</span>,
#  <span class="preu">5.871</span>,
#  <span class="preu">526.12</span>,
#  <span class="preu">120.40</span>,
#  <span class="preu">1.300</span>,
#  <span class="preu">165.61</span>,
#  <span class="preu">43.60</span>,
#  <span class="preu">58.77</span>,
#  <span class="preu">6.050</span>,
#  <span class="preu">6.180</span>,
#  <span class="preu">119.70</span>,
#  <span class="preu">157.35</span>,
#  <span class="preu">1280</span>,
#  <span class="preu">5388</span>,
#  <span class="preu">26.50</span>,
#  <span class="preu">43.89</span>,
#  <span class="preu">36.86</span>,
#  <span class="preu">4985</span>]

# %%
argtag = soup.find('div',{'data-id': '149'}).getText()
argtag
# Out:
# 'ArgentineLive17 Jul 158.77ARSkg1.170 2.0%'

# %%
bratag1 = soup.find('div',{'data-id': '122'}).getText()
bratag1
# Out:
# 'Brazil - ParanáLive27 Jul6.050BRLkg0.850 16.3%'

# %%
bratag2 = soup.find('div',{'data-id': '121'}).getText()
bratag2
# Out:
# 'Brazil - Santa CatarinaLive23 Jul 16.180BRLkg0.100 1.6%'

# %%
cantag1 = soup.find('div',{'data-id': '94'}).getText()
cantag1
# Out:
# 'Canada - OntarioCarcass24 Jul 5119.70CAD100kg4.980 4.3%'

# %%
cantag2 = soup.find('div',{'data-id': '92'}).getText()
cantag2
# Out:
# 'Canada - QuebecCarcass24 Jul157.35CAD100kg4.200 2.7%'

# %%
chitag = soup.find('div',{'data-id': '86'}).getText()
chitag
# Out:
# 'ChileLive24 Jul 41280CLPkg40.00 3.2%'

# %%
mextag = soup.find('div',{'data-id': '113'}).getText()
mextag
# Out:
# 'Mexico - SonoraLive24 Jul26.50MXNkg26.50 inf%'

# %%
coltag = soup.find('div',{'data-id': '148'}).getText()
coltag
# Out:
# 'ColombiaLive24 Jul5388COPkg98.00 1.9%'

# %%
usatag = soup.find('div',{'data-id': '93'}).getText()
usatag
# Out:
# 'USA - Iowa/Minnesota27 Jul4.730'

# %%
kortag = soup.find('div',{'data-id': '90'}).getText()
kortag
# Out:
# 'South KoreaCarcass23 Jul4985KRWkg110.00 2.2%'

# %%
poltag = soup.find('div',{'data-id': '107'}).getText()
poltag
# Out:
# 'PolandCarcass 57%17 Jul 25.871PLNkg0.444 7.0%'

# %%
chitag = soup.find('div',{'data-id': '106'}).getText()
chitag
# Out:
# 'China15 Jul0.780'

# %%
grbtag = soup.find('div',{'data-id': '82'}).getText()
grbtag
# Out:
# 'United KingdomSPP Euro Spec18 Jul 2165.61GBXkg0.250 0.2%'

# %%
nedtag = soup.find('div',{'data-id': '4'}).getText()
nedtag
# Out:
# 'Netherlands - BeursprijsLive17 Jul 11.050EURkg0.000 0%'

# %%
romtag = soup.find('div',{'data-id': '123'}).getText()
romtag
# Out:
# 'RomaniaLive24 Jul526.12RON100kg30.01 5.4%'

# %%
fratag = soup.find('div',{'data-id': '14'}).getText()
fratag
# Out:
# 'France - MPBCarcass 56 TMV27 Jul 11.293EURkg0.000 0%'

# %%
rustag = soup.find('div',{'data-id': '111'}).getText()
rustag
# Out:
# 'RussiaLive22 Jul 3120.40RUBkg3.100 2.6%'

# %%
dentag = soup.find('div',{'data-id': '56'}).getText()
dentag
# Out:
# 'DenmarkCarcass 60%23 Jul 110.50DKKkg0.000 0%'

# %%
beltag = soup.find('div',{'data-id': '6'}).getText()
beltag
# Out:
# 'Belgium - DanisLive23 Jul 10.940EURkg0.000 0%'

# %%
esptag = soup.find('div',{'data-id': '2'}).getText()
esptag
# Out:
# 'Spain - Lleida23 Jul0.000'

# %%
gertag = soup.find('div',{'data-id': '3'}).getText()
gertag
# Out:
# 'Germany29 Jul0.000'

# %%
ukrtag = soup.find('div',{'data-id': '110'}).getText()
ukrtag
# Out:
# 'UkraineLive3 Jul 243.60UAHkg0.920 2.1%'

# %% [markdown]
# ### Setting Varibales to store the data you want

# %%
cards = []
card = {}

# %% [markdown]
# ### Checking value on a single card

# %%
quote = soup.find('span', {'class': 'preu'}).getText()
quote
# Out:
# '0.940'

# %%
card['price'] = soup.find('span', {'class': 'preu'}).getText()

# %%
card
# Out:
# {'price': '0.940'}

# %% [markdown]
# ### <font color=red>Resumo

# %%
# Valor
card['price'] = soup.find('span', {'class': 'preu'}).getText()

# %% [markdown]
# # 2. Checking the other information related to the quotation

# %%
soup.find('div', {'class':'col-preu'})
# Out:
# <div class="col-preu"><i class="diferencia fa fa-caret-up up"></i><span class="diferencia perc up">4.730</span></div>

# %%
for info in infos:
    print(info.get('class'), ' - ', info.get_text())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-8743edb47106> in <module>
# ----> 1 for info in infos:
#       2     print(info.get('class'), ' - ', info.get_text())
#
# NameError: name 'infos' is not defined

# %%
for info in infos:
    print(info.get('class'), ' - ', info.get_text())
# Out:
# ['txt-name', 'inline']  -  LAMBORGHINI AVENTADOR
# ['txt-category', 'badge', 'badge-secondary', 'inline']  -  USADO
# ['txt-motor']  -  Motor 1.8 16v
# ['txt-description']  -  Ano 1993 - 55.286 km
# ['txt-location']  -  Belo Horizonte - MG

# %%
for info in infos:
    print(info.get('class')[0], ' - ', info.get_text())
# Out:
# txt-name  -  LAMBORGHINI AVENTADOR
# txt-category  -  USADO
# txt-motor  -  Motor 1.8 16v
# txt-description  -  Ano 1993 - 55.286 km
# txt-location  -  Belo Horizonte - MG

# %%
for info in infos:
    print(info.get('class')[0].split('-'), ' - ', info.get_text())
# Out:
# ['txt', 'name']  -  LAMBORGHINI AVENTADOR
# ['txt', 'category']  -  USADO
# ['txt', 'motor']  -  Motor 1.8 16v
# ['txt', 'description']  -  Ano 1993 - 55.286 km
# ['txt', 'location']  -  Belo Horizonte - MG

# %%
for info in infos:
    print(info.get('class')[0].split('-')[-1], ' - ', info.get_text())
# Out:
# name  -  LAMBORGHINI AVENTADOR
# category  -  USADO
# motor  -  Motor 1.8 16v
# description  -  Ano 1993 - 55.286 km
# location  -  Belo Horizonte - MG

# %%
for info in infos:
    card[info.get('class')[0].split('-')[-1]] = info.get_text()

# %%
card
# Out:
# {'value': 'R$ 338.000',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'category': 'USADO',
#  'motor': 'Motor 1.8 16v',
#  'description': 'Ano 1993 - 55.286 km',
#  'location': 'Belo Horizonte - MG'}

# %% [markdown]
# ### <font color=red>Resumo

# %%
# Informações
infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
for info in infos:
    card[info.get('class')[0].split('-')[-1]] = info.get_text()

# %% [markdown]
# # 5.4. Obtendo os ACESSÓRIOS do veículo anunciado

# %%
anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>,
#  <li class="txt-items">...</li>]

# %%
items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
items
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>,
#  <li class="txt-items">...</li>]

# %%
items.pop()
# Out:
# <li class="txt-items">...</li>

# %%
items
# Out:
# [<li class="txt-items">► 4 X 4</li>,
#  <li class="txt-items">► Câmera de estacionamento</li>,
#  <li class="txt-items">► Controle de tração</li>,
#  <li class="txt-items">► Sensor de estacionamento</li>]

# %%
for item in items:
    print(item.getText().replace('► ', ''))
# Out:
# 4 X 4
# Câmera de estacionamento
# Controle de tração
# Sensor de estacionamento

# %%
acessorios = []
for item in items:
    acessorios.append(item.getText().replace('► ', ''))
    
acessorios
# Out:
# ['4 X 4',
#  'Câmera de estacionamento',
#  'Controle de tração',
#  'Sensor de estacionamento']

# %%
card['items'] = acessorios

# %%
card
# Out:
# {'value': 'R$ 338.000',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'category': 'USADO',
#  'motor': 'Motor 1.8 16v',
#  'description': 'Ano 1993 - 55.286 km',
#  'location': 'Belo Horizonte - MG',
#  'items': ['4 X 4',
#   'Câmera de estacionamento',
#   'Controle de tração',
#   'Sensor de estacionamento']}

# %% [markdown]
# ### <font color=red>Resumo

# %%
# Acessórios
items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
items.pop()
acessorios = []
for item in items:
    acessorios.append(item.getText().replace('► ', ''))
card['items'] = acessorios

# %% [markdown]
# # 5.5 Criando um DataFrame com os dados coletados do Alura Motors

# %%
card
# Out:
# {'value': 'R$ 338.000',
#  'name': 'LAMBORGHINI AVENTADOR',
#  'category': 'USADO',
#  'motor': 'Motor 1.8 16v',
#  'description': 'Ano 1993 - 55.286 km',
#  'location': 'Belo Horizonte - MG',
#  'items': ['4 X 4',
#   'Câmera de estacionamento',
#   'Controle de tração',
#   'Sensor de estacionamento']}

# %%
import pandas as pd

# %%
dataset = pd.DataFrame(card)

# %%
dataset
# Out:
#         value                   name category          motor  \
# 0  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
# 1  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
# 2  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
# 3  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
#
#             description             location                     items
# 0  Ano 1993 - 55.286 km  Belo Horizonte - MG                     4 X 4
# 1  Ano 1993 - 55.286 km  Belo Horizonte - MG  Câmera de estacionamento
# 2  Ano 1993 - 55.286 km  Belo Horizonte - MG        Controle de tração
# 3  Ano 1993 - 55.286 km  Belo Horizonte - MG  Sensor de estacionamento

# %%
dataset = pd.DataFrame.from_dict(card, orient = 'index')
dataset
# Out:
#                                                              0
# value                                               R$ 338.000
# name                                     LAMBORGHINI AVENTADOR
# category                                                 USADO
# motor                                            Motor 1.8 16v
# description                               Ano 1993 - 55.286 km
# location                                   Belo Horizonte - MG
# items        [4 X 4, Câmera de estacionamento, Controle de ...

# %%
dataset = pd.DataFrame.from_dict(card, orient = 'index').T
dataset
# Out:
#         value                   name category          motor  \
# 0  R$ 338.000  LAMBORGHINI AVENTADOR    USADO  Motor 1.8 16v
#
#             description             location  \
# 0  Ano 1993 - 55.286 km  Belo Horizonte - MG
#
#                                                items
# 0  [4 X 4, Câmera de estacionamento, Controle de ...

# %%
dataset.to_csv('./output/data/dataset.csv', sep=';', index = False, encoding = 'utf-8-sig')

# %% [markdown]
# # <font color=green>6. WEB SCRAPING DO SITE ALURA MOTORS - OBTENDO OS DADOS DE TODOS OS ANÚNCIOS DE UMA PÁGINA

# %% [markdown]
# # 6.1. Identificando as informações no HTML

# %%
len(soup.find('div', {"id": "container-cards"}).findAll('div', class_="card"))
# Out:
# 10

# %%
anuncios = soup.find('div', {"id": "container-cards"}).findAll('div', class_="card")

# %%
for anuncio in anuncios:
    print(str(anuncio) + "\n\n")
# Out:
# <div class="well card">
# <div class="col-md-3 image-card">
# <img alt="Foto" height="155" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/lamborghini-aventador/lamborghini-aventador-2932196__340.jpg" width="220"/>
# </div>
# <div class="col-md-6 body-card">
# <p class="txt-name inline">LAMBORGHINI AVENTADOR</p>
# <p class="txt-category badge badge-secondary inline">USADO</p>
# <p class="txt-motor">Motor 1.8 16v</p>
# <p class="txt-description">Ano 1993 - 55.286 km</p>
# <ul class="lst-items">
# <li class="txt-items">► 4 X 4</li>
# <li class="txt-items">► Câmera de estacionamento</li>
# <li class="txt-items">► Controle de tração</li>
# <li class="txt-items">► Sensor de estacionamento</li>
# <li class="txt-items">...</li>
# </ul>
# <p class="txt-location">Belo Horizonte - MG</p>
# </div>
# <div class="col-md-3 value-card">
# <div class="value">
# <p class="txt-value">R$ 338.000</p>
# </div>
# </div>
# </div>
#
#
# <div class="well card">
# ...

# %% [markdown]
# # 6.2. Criando uma rotina de scraping

# %%
# Importando bibliotecas
from urllib.request import urlopen, urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

# Declarando variável cards
cards = []

# Obtendo o HTML
response = urlopen('https://alura-site-scraping.herokuapp.com/index.php')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')

# Obtendo as TAGs de interesse
anuncios = soup.find('div', {"id": "container-cards"}).findAll('div', class_="card")

# Coletando as informações dos CARDS
for anuncio in anuncios:
    card = {}
    
    # Valor
    card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

    # Informações
    infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
    for info in infos:
        card[info.get('class')[0].split('-')[-1]] = info.get_text()

    # Acessórios
    items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
    items.pop()
    acessorios = []
    for item in items:
        acessorios.append(item.get_text().replace('► ', ''))
    card['items'] = acessorios
    
    # Adicionando resultado a lista cards
    cards.append(card)

    # Imagens
    image = anuncio.find('div', {'class': 'image-card'}).img
    urlretrieve(image.get('src'), './output/img/' + image.get('src').split('/')[-1])     

# Criando um DataFrame com os resultados
dataset = pd.DataFrame(cards)
dataset.to_csv('./output/data/dataset.csv', sep=';', index = False, encoding = 'utf-8-sig')
dataset
# Out:
#   category           description  \
# 0    USADO  Ano 1993 - 55.286 km
# 1    USADO  Ano 2018 - 83.447 km
# 2    USADO  Ano 2004 - 19.722 km
# 3    USADO  Ano 1992 - 34.335 km
# 4    USADO     Ano 1991 - 464 km
# 5    USADO  Ano 2004 - 50.189 km
# 6    USADO  Ano 2014 - 17.778 km
# 7    USADO  Ano 2009 - 81.251 km
# 8     NOVO       Ano 2019 - 0 km
# 9    USADO  Ano 1999 - 12.536 km
#
#                                                items             location  \
# 0  [4 X 4, Câmera de estacionamento, Controle de ...  Belo Horizonte - MG
# 1  [Câmera de estacionamento, Controle de estabil...  Belo Horizonte - MG
# 2  [Central multimídia, Bancos de couro, Rodas de...  Rio de Janeiro - RJ
# 3  [Bancos de couro, Freios ABS, Rodas de liga, C...       São Paulo - SP
# 4  [Central multimídia, Teto panorâmico, Sensor c...  Belo Horizonte - MG
# 5  [Painel digital, Controle de tração, Teto pano...  Belo Horizonte - MG
# ...

# %%
cards
