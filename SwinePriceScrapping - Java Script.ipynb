# %%
#Importing libraries for acessing the content on the web
import bs4
import urllib.request as urllib_request
import pandas

print("BeautifulSoup ->", bs4.__version__)
print("urllib ->", urllib_request.__version__)
print("pandas ->", pandas.__version__)

from urllib.request import urlopen
from bs4 import BeautifulSoup

#targetting website page to scrap
url = 'https://www.pig333.com/markets_and_prices/'

response = urlopen(url)
html = response.read()
#shaping pages characteres
html = html.decode('utf-8')

soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# BeautifulSoup -> 4.8.2
# urllib -> 3.7
# pandas -> 1.0.1
# <!DOCTYPE html>
# <html class="web">
#  <head>
#   <title>
#    Pig prices - pig333, pig to pork community
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="en" http-equiv="content-language"/>
#   <meta content="The latest slaughter pig prices in the most important pig markets. Check the evolution of the historical prices in charts and in several currencies." name="description"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta charset="utf-8"/>
#   <meta content="POnbcF9y7hlMA1qCHewt_IU_bNjPhXwcwidy38TUjms" name="google-site-verification"/>
#   <meta content="BG_3ZIOxC_wqzmPDZHbVdH-u5i_wLT5XdX2n_0_66Ck" name="google-site-verification"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:900,700,400|Lato:400,400i,700,900,900i|Merriweather&amp;display=swap&amp;subset=cyrillic,latin-ext" rel="stylesheet"/>
# ...

# %%
from jupyter_core.paths import jupyter_config_dir
jupyter_dir = jupyter_config_dir()
jupyter_dir
# Out:
# '/Users/lstorino/.jupyter'

# %%
import os.path
parser_js_path = os.path.join(jupyter_dir, 'parser', 'parser.js')

#  my custom js
if os.path.isfile(parser_js_path):
    with open(parser_js_path) as f:
      print(f.read())
else:
    print("Se fudeu, You don't have a parser.js file!")
# Out:
# $(".preu_mercat").map((key, div) => {
#     div = $(div);
#     let obj = {};
#     obj.location = div.find(".titol")[0].innerHTML;
#     let priceSpan = div.find(".preu")[0];
#     if(priceSpan) obj.price = priceSpan.innerHTML;
#     else return null;
#
#     let currSpan = div.find(".moneda")[0];
#     if(currSpan) obj.currency = currSpan.innerHTML;
#     let dateSpan = div.find(".data")[0];
#     if(currSpan) obj.date = dateSpan.innerHTML;
#     return obj;
# });
